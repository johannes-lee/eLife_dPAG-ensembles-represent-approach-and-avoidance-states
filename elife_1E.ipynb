# %%
import os
os.chdir('../')
from helpers import *
# Out:
# mousenums:  ['230', '355', '358', '362', '673', '674', '816', '825']

# %%
#1a
track, neur, behav = getdicts(foldnames, 355, 'epm')
mpos = track['mouse_positionMS']
calc = neur['C_raw']
plotheatmap(mpos, calc[:, 2])
ax = plt.gca()
ax.axis('off')

plt.savefig('./elife_figs/1Et.svg')
# Out:
# (-0.5, 516.5, 0.0, 511.0)

# %%
#1b
track, neur, behav = getdicts(foldnames, 355, 'epm')
mpos = track['mouse_positionMS']
calc = neur['C_raw']
plotheatmap(mpos, calc[:, 14])
ax = plt.gca()
ax.axis('off')

plt.savefig('./elife_figs/1Eb.svg')
# Out:
# (-0.5, 516.5, 0.0, 511.0)
